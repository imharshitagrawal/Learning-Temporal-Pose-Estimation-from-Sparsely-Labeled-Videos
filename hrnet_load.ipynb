# %%
#%cd /content/drive/My Drive/Learning Temporal Pose Estimation/simple-HRNet

# %%
#pip install -r requirements.txt

# %%
# ! git submodule update --init --recursive

# %%
#%cd /content/drive/My Drive/Learning Temporal Pose Est#%cd /content/drive/My Drive/Learning Temporal Pose Estimation/simple-HRNet/models/detectors/yolo/weightsimation/simple-HRNet/models/detectors/yolo
#! pip install -r requirements.txt

# %%
#%cd /content/drive/My Drive/Learning Temporal Pose Estimation/simple-HRNet/models/detectors/yolo/weights

# %%
#! bash download_weights.sh
